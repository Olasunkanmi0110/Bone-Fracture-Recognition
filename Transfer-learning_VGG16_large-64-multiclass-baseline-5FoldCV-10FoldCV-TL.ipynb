# %% [markdown]
# # Introduction
# - The goal of this section is to train a convolutional neural network on custom images (radiographss) from scratch. To achieve this, there are few operations we need to perform, which includes:
#   - Connecting google colab to our google drive
#   - Data Preparation: creating training and test data from the raw data
#   - Building the CNN architecture
#   - Training the network with and without transfer learning using pretrained models such as Vgg16, ResNet50, DenseNet121, MobileNetV1 and EfficientNet
#
#
# - Dataset:https://stanfordmlgroup.github.io/competitions/mura/

# %%
# Connect Google Colab to Google Drive
# from google.colab import drive
# drive.mount("/content/drive")

# %%
# install opencv-python
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\olasunkanmi\anaconda3\lib\site-packages (4.8.1.78)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\olasunkanmi\anaconda3\lib\site-packages (from opencv-python) (1.23.0)
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# install keras-tuner

# !pip install keras-tuner
# Out:
# Requirement already satisfied: keras-tuner in c:\users\olasunkanmi\anaconda3\lib\site-packages (1.4.7)
# Requirement already satisfied: keras in c:\users\olasunkanmi\anaconda3\lib\site-packages (from keras-tuner) (2.12.0)
# Requirement already satisfied: packaging in c:\users\olasunkanmi\anaconda3\lib\site-packages (from keras-tuner) (21.3)
# Requirement already satisfied: requests in c:\users\olasunkanmi\anaconda3\lib\site-packages (from keras-tuner) (2.28.1)
# Requirement already satisfied: kt-legacy in c:\users\olasunkanmi\anaconda3\lib\site-packages (from keras-tuner) (1.0.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\olasunkanmi\anaconda3\lib\site-packages (from packaging->keras-tuner) (3.0.9)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\olasunkanmi\anaconda3\lib\site-packages (from requests->keras-tuner) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\olasunkanmi\anaconda3\lib\site-packages (from requests->keras-tuner) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\olasunkanmi\anaconda3\lib\site-packages (from requests->keras-tuner) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\olasunkanmi\anaconda3\lib\site-packages (from requests->keras-tuner) (2024.2.2)
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# # largedataset 64 multiclass train-test split

# %%
# import the required libraries
import cv2
import numpy as np
import os
import shutil
import random

import tensorflow as tf
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, Flatten, BatchNormalization
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

from tensorflow import keras
import keras_tuner as kt

from tensorflow.keras.optimizers import Adam

import matplotlib.pyplot as plt

# %%
#Clearing backend
from tensorflow.keras import backend
backend.clear_session()

#Fixing the seed for random number generators
np.random.seed(1042)
import random
random.seed(1042)
tf.random.set_seed(1042)

# %% [markdown]
# # largedata 64 multiclass gridsearch (VGG16)

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.models import Model
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import seaborn as sns

# Define paths
train_dir = "C:/Users/OLASUNKANMI/Desktop/UoL DS Course files/Semester C/UoL Research Project Materials/New_Mura/large_dataset/64/Multiclass/train"
test_dir = "C:/Users/OLASUNKANMI/Desktop/UoL DS Course files/Semester C/UoL Research Project Materials/New_Mura/large_dataset/64/Multiclass/test"


# Data Preprocessing
image_size = (64, 64)
batch_size = 32

datagen = ImageDataGenerator(rescale=1./255, validation_split=0.3)

train_generator = datagen.flow_from_directory(
    train_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='training')

val_generator = datagen.flow_from_directory(
    train_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation')

test_datagen = ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False)

# Load VGG16 Model
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(64, 64, 3))
base_model.trainable = False  # Freeze base model

# Add Custom Layers
x = Flatten()(base_model.output)
x = Dense(512, activation='relu')(x)
x = Dropout(0.5)(x)
out = Dense(7, activation='softmax')(x)
model = Model(inputs=base_model.input, outputs=out)

# Compile Model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train Model
history = model.fit(train_generator, validation_data=val_generator, epochs=10)

# Evaluate on Test Data
y_true = test_generator.classes
y_pred_probs = model.predict(test_generator)
y_pred = np.argmax(y_pred_probs, axis=1)

# Classification Report
print("Classification Report:")
print(classification_report(y_true, y_pred, target_names=test_generator.class_indices.keys()))

# Confusion Matrix
cm = confusion_matrix(y_true, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=test_generator.class_indices.keys(), yticklabels=test_generator.class_indices.keys())
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# Calculate Sensitivity and Specificity
sensitivity = cm.diagonal() / cm.sum(axis=1)
specificity = cm.diagonal() / cm.sum(axis=0)
print("Sensitivity:", sensitivity)
print("Specificity:", specificity)

# Visualize the loss
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, label="Training")
plt.plot(epochs, val_loss, label="Validation")
plt.legend(loc="best")
plt.show()
# Out:
# Found 2744 images belonging to 7 classes.
# Found 1176 images belonging to 7 classes.
# Found 1680 images belonging to 7 classes.
# Epoch 1/10
# 86/86 [==============================] - 1741s 20s/step - loss: 1.4150 - accuracy: 0.4832 - val_loss: 1.0212 - val_accuracy: 0.6658
# Epoch 2/10
# 86/86 [==============================] - 1669s 19s/step - loss: 0.9922 - accuracy: 0.6501 - val_loss: 0.8654 - val_accuracy: 0.6896
# Epoch 3/10
# 86/86 [==============================] - 1600s 19s/step - loss: 0.8490 - accuracy: 0.6986 - val_loss: 0.7611 - val_accuracy: 0.7338
# Epoch 4/10
# 86/86 [==============================] - 1503s 18s/step - loss: 0.7625 - accuracy: 0.7362 - val_loss: 0.7581 - val_accuracy: 0.7270
# Epoch 5/10
# 86/86 [==============================] - 1504s 18s/step - loss: 0.6802 - accuracy: 0.7591 - val_loss: 0.7002 - val_accuracy: 0.7560
# Epoch 6/10
# 86/86 [==============================] - 1506s 18s/step - loss: 0.6108 - accuracy: 0.7857 - val_loss: 0.7069 - val_accuracy: 0.7457
# Epoch 7/10
# 86/86 [==============================] - 5594s 66s/step - loss: 0.5912 - accuracy: 0.7952 - val_loss: 0.6807 - val_accuracy: 0.7534
# Epoch 8/10
# 86/86 [==============================] - 1120s 13s/step - loss: 0.5336 - accuracy: 0.8109 - val_loss: 0.6554 - val_accuracy: 0.7670
# Epoch 9/10
# 86/86 [==============================] - 1414s 17s/step - loss: 0.5083 - accuracy: 0.8196 - val_loss: 0.6207 - val_accuracy: 0.7823
# Epoch 10/10
# 86/86 [==============================] - 1433s 17s/step - loss: 0.4725 - accuracy: 0.8382 - val_loss: 0.6402 - val_accuracy: 0.7721
# 53/53 [==============================] - 682s 13s/step
# Classification Report:
#               precision    recall  f1-score   support
#
#     XR_ELBOW       0.68      0.71      0.70       240
#    XR_FINGER       0.72      0.88      0.79       240
#   XR_FOREARM       0.72      0.63      0.67       240
#      XR_HAND       0.86      0.90      0.88       240
#   XR_HUMERUS       0.90      0.71      0.79       240
#  XR_SHOULDER       0.86      0.88      0.87       240
#     XR_WRIST       0.80      0.82      0.81       240
#
#     accuracy                           0.79      1680
#    macro avg       0.79      0.79      0.79      1680
# weighted avg       0.79      0.79      0.79      1680
# Sensitivity: [0.7125     0.875      0.62916667 0.89583333 0.70833333 0.875
#  0.825     ]
# Specificity: [0.684      0.72413793 0.71904762 0.85657371 0.8994709  0.86419753
#  0.80161943]

# %%
#Clearing backend
from tensorflow.keras import backend
backend.clear_session()

#Fixing the seed for random number generators
np.random.seed(1042)
import random
random.seed(1042)
tf.random.set_seed(1042)

# %% [markdown]
# # largedata 64 multiclass 5-Fold CV vgg16

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.models import Model
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import seaborn as sns
from sklearn.model_selection import KFold

# Define paths
train_dir = "C:/Users/OLASUNKANMI/Desktop/UoL DS Course files/Semester C/UoL Research Project Materials/New_Mura/large_dataset/64/Multiclass/train"
test_dir = "C:/Users/OLASUNKANMI/Desktop/UoL DS Course files/Semester C/UoL Research Project Materials/New_Mura/large_dataset/64/Multiclass/test"

# Data Preprocessing
image_size = (64, 64)
batch_size = 32
cv_folds = 5

# Image Data Generators
datagen = ImageDataGenerator(rescale=1./255, validation_split=0.3)

def create_model():
    base_model = VGG16(weights='imagenet', include_top=False, input_shape=(64, 64, 3))
    base_model.trainable = False  # Freeze base model
    
    x = Flatten()(base_model.output)
    x = Dense(512, activation='relu')(x)
    x = Dropout(0.5)(x)
    out = Dense(7, activation='softmax')(x)
    model = Model(inputs=base_model.input, outputs=out)
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# Perform Cross-Validation
kf = KFold(n_splits=cv_folds, shuffle=True, random_state=42)

for fold, (train_index, val_index) in enumerate(kf.split(train_generator.filenames)):
    print(f"Training fold {fold+1}/{cv_folds}")
    
    train_generator = datagen.flow_from_directory(
        train_dir,
        target_size=image_size,
        batch_size=batch_size,
        class_mode='categorical',
        subset='training')
    
    val_generator = datagen.flow_from_directory(
        train_dir,
        target_size=image_size,
        batch_size=batch_size,
        class_mode='categorical',
        subset='validation')
    
    model = create_model()
    history = model.fit(train_generator, validation_data=val_generator, epochs=10)

# Evaluate on Test Data
test_datagen = ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False)

y_true = test_generator.classes
y_pred_probs = model.predict(test_generator)
y_pred = np.argmax(y_pred_probs, axis=1)

# Classification Report
print("Classification Report:")
print(classification_report(y_true, y_pred, target_names=test_generator.class_indices.keys()))

# Confusion Matrix
cm = confusion_matrix(y_true, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=test_generator.class_indices.keys(), yticklabels=test_generator.class_indices.keys())
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# Sensitivity and Specificity
sensitivity = cm.diagonal() / cm.sum(axis=1)
specificity = cm.diagonal() / cm.sum(axis=0)
print("Sensitivity:", sensitivity)
print("Specificity:", specificity)

# Loss Visualization
plt.plot(history.history["loss"], label="Training Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.legend()
plt.title("Training and Validation Loss")
plt.show()
# Out:
# Training fold 1/5
# Found 2744 images belonging to 7 classes.
# Found 1176 images belonging to 7 classes.
# Epoch 1/10
# 86/86 [==============================] - 1741s 20s/step - loss: 1.4150 - accuracy: 0.4832 - val_loss: 1.0212 - val_accuracy: 0.6658
# Epoch 2/10
# 86/86 [==============================] - 1772s 21s/step - loss: 0.9922 - accuracy: 0.6501 - val_loss: 0.8654 - val_accuracy: 0.6896
# Epoch 3/10
# 86/86 [==============================] - 1710s 20s/step - loss: 0.8490 - accuracy: 0.6986 - val_loss: 0.7611 - val_accuracy: 0.7338
# Epoch 4/10
# 86/86 [==============================] - 1670s 19s/step - loss: 0.7625 - accuracy: 0.7362 - val_loss: 0.7581 - val_accuracy: 0.7270
# Epoch 5/10
# 86/86 [==============================] - 1656s 19s/step - loss: 0.6802 - accuracy: 0.7591 - val_loss: 0.7002 - val_accuracy: 0.7560
# Epoch 6/10
# 86/86 [==============================] - 1637s 19s/step - loss: 0.6108 - accuracy: 0.7857 - val_loss: 0.7069 - val_accuracy: 0.7457
# Epoch 7/10
# 86/86 [==============================] - 1433s 17s/step - loss: 0.5912 - accuracy: 0.7952 - val_loss: 0.6807 - val_accuracy: 0.7534
# Epoch 8/10
# 86/86 [==============================] - 1477s 17s/step - loss: 0.5336 - accuracy: 0.8109 - val_loss: 0.6554 - val_accuracy: 0.7670
# Epoch 9/10
# 86/86 [==============================] - 1409s 16s/step - loss: 0.5083 - accuracy: 0.8196 - val_loss: 0.6207 - val_accuracy: 0.7823
# Epoch 10/10
# 86/86 [==============================] - 1322s 15s/step - loss: 0.4725 - accuracy: 0.8382 - val_loss: 0.6402 - val_accuracy: 0.7721
# Training fold 2/5
# Found 2744 images belonging to 7 classes.
# Found 1176 images belonging to 7 classes.
# Epoch 1/10
# 86/86 [==============================] - 1289s 15s/step - loss: 1.3823 - accuracy: 0.5091 - val_loss: 0.9871 - val_accuracy: 0.6735
# Epoch 2/10
# 86/86 [==============================] - 1221s 14s/step - loss: 0.9875 - accuracy: 0.6509 - val_loss: 0.8543 - val_accuracy: 0.7066
# Epoch 3/10
# 86/86 [==============================] - 1243s 14s/step - loss: 0.8552 - accuracy: 0.6950 - val_loss: 0.8105 - val_accuracy: 0.7134
# Epoch 4/10
# 86/86 [==============================] - 4632s 54s/step - loss: 0.7517 - accuracy: 0.7329 - val_loss: 0.7336 - val_accuracy: 0.7219
# Epoch 5/10
# 86/86 [==============================] - 1079s 13s/step - loss: 0.6854 - accuracy: 0.7551 - val_loss: 0.6906 - val_accuracy: 0.7449
# Epoch 6/10
# 86/86 [==============================] - 1068s 12s/step - loss: 0.5936 - accuracy: 0.7905 - val_loss: 0.6761 - val_accuracy: 0.7619
# Epoch 7/10
# 86/86 [==============================] - 1082s 13s/step - loss: 0.5484 - accuracy: 0.8087 - val_loss: 0.6473 - val_accuracy: 0.7534
# Epoch 8/10
# 86/86 [==============================] - 1086s 13s/step - loss: 0.5206 - accuracy: 0.8189 - val_loss: 0.6201 - val_accuracy: 0.7730
# Epoch 9/10
# 86/86 [==============================] - 1077s 13s/step - loss: 0.5009 - accuracy: 0.8305 - val_loss: 0.6324 - val_accuracy: 0.7755
# Epoch 10/10
# 86/86 [==============================] - 1028s 12s/step - loss: 0.4635 - accuracy: 0.8429 - val_loss: 0.6023 - val_accuracy: 0.7891
# Training fold 3/5
# Found 2744 images belonging to 7 classes.
# Found 1176 images belonging to 7 classes.
# Epoch 1/10
# 86/86 [==============================] - 1088s 13s/step - loss: 1.4331 - accuracy: 0.4858 - val_loss: 1.0170 - val_accuracy: 0.6412
# Epoch 2/10
# 86/86 [==============================] - 1079s 13s/step - loss: 0.9798 - accuracy: 0.6662 - val_loss: 0.8458 - val_accuracy: 0.7066
# Epoch 3/10
# 86/86 [==============================] - 1075s 13s/step - loss: 0.8358 - accuracy: 0.7190 - val_loss: 0.8126 - val_accuracy: 0.7058
# Epoch 4/10
# 86/86 [==============================] - 19649s 231s/step - loss: 0.7485 - accuracy: 0.7431 - val_loss: 0.7673 - val_accuracy: 0.7160
# Epoch 5/10
# 86/86 [==============================] - 1059s 12s/step - loss: 0.6757 - accuracy: 0.7726 - val_loss: 0.7096 - val_accuracy: 0.7406
# Epoch 6/10
# 86/86 [==============================] - 1077s 13s/step - loss: 0.6256 - accuracy: 0.7828 - val_loss: 0.6956 - val_accuracy: 0.7423
# Epoch 7/10
# 86/86 [==============================] - 1071s 12s/step - loss: 0.5905 - accuracy: 0.7937 - val_loss: 0.6786 - val_accuracy: 0.7509
# Epoch 8/10
# 86/86 [==============================] - 1078s 13s/step - loss: 0.5479 - accuracy: 0.8127 - val_loss: 0.6730 - val_accuracy: 0.7645
# Epoch 9/10
# 86/86 [==============================] - 1076s 13s/step - loss: 0.5028 - accuracy: 0.8284 - val_loss: 0.6477 - val_accuracy: 0.7611
# Epoch 10/10
# 86/86 [==============================] - 1076s 13s/step - loss: 0.4688 - accuracy: 0.8378 - val_loss: 0.6413 - val_accuracy: 0.7789
# Training fold 4/5
# Found 2744 images belonging to 7 classes.
# Found 1176 images belonging to 7 classes.
# Epoch 1/10
# 86/86 [==============================] - 1105s 13s/step - loss: 1.3928 - accuracy: 0.4971 - val_loss: 1.0049 - val_accuracy: 0.6590
# Epoch 2/10
# 86/86 [==============================] - 1176s 14s/step - loss: 0.9901 - accuracy: 0.6542 - val_loss: 0.8623 - val_accuracy: 0.7075
# Epoch 3/10
# 86/86 [==============================] - 1325s 15s/step - loss: 0.8374 - accuracy: 0.6986 - val_loss: 0.7829 - val_accuracy: 0.7270
# Epoch 4/10
# 86/86 [==============================] - 1400s 16s/step - loss: 0.7394 - accuracy: 0.7391 - val_loss: 0.7550 - val_accuracy: 0.7406
# Epoch 5/10
# 86/86 [==============================] - 1688s 20s/step - loss: 0.6941 - accuracy: 0.7511 - val_loss: 0.6914 - val_accuracy: 0.7381
# Epoch 6/10
# 86/86 [==============================] - 2029s 24s/step - loss: 0.6238 - accuracy: 0.7741 - val_loss: 0.6895 - val_accuracy: 0.7457
# Epoch 7/10
# 86/86 [==============================] - 4449s 52s/step - loss: 0.5770 - accuracy: 0.7941 - val_loss: 0.6486 - val_accuracy: 0.7670
# Epoch 8/10
# 86/86 [==============================] - 1565s 18s/step - loss: 0.5416 - accuracy: 0.8061 - val_loss: 0.6531 - val_accuracy: 0.7696
# Epoch 9/10
# 86/86 [==============================] - 1938s 23s/step - loss: 0.4971 - accuracy: 0.8258 - val_loss: 0.6560 - val_accuracy: 0.7636
# Epoch 10/10
# 86/86 [==============================] - 2073s 24s/step - loss: 0.4904 - accuracy: 0.8258 - val_loss: 0.6180 - val_accuracy: 0.7679
# Training fold 5/5
# Found 2744 images belonging to 7 classes.
# Found 1176 images belonging to 7 classes.
# Epoch 1/10
# 86/86 [==============================] - 2190s 25s/step - loss: 1.4229 - accuracy: 0.4851 - val_loss: 1.0668 - val_accuracy: 0.6318
# Epoch 2/10
# 86/86 [==============================] - 2172s 25s/step - loss: 0.9778 - accuracy: 0.6574 - val_loss: 0.8774 - val_accuracy: 0.6854
# Epoch 3/10
# 86/86 [==============================] - 10404s 122s/step - loss: 0.8152 - accuracy: 0.7267 - val_loss: 0.8314 - val_accuracy: 0.6990
# Epoch 4/10
# 86/86 [==============================] - 1994s 23s/step - loss: 0.7352 - accuracy: 0.7511 - val_loss: 0.7261 - val_accuracy: 0.7372
# Epoch 5/10
# 86/86 [==============================] - 4349s 51s/step - loss: 0.6667 - accuracy: 0.7628 - val_loss: 0.6920 - val_accuracy: 0.7415
# Epoch 6/10
# 86/86 [==============================] - 2095s 25s/step - loss: 0.6150 - accuracy: 0.7850 - val_loss: 0.6979 - val_accuracy: 0.7398
# Epoch 7/10
# 86/86 [==============================] - 2423s 28s/step - loss: 0.5719 - accuracy: 0.7992 - val_loss: 0.6612 - val_accuracy: 0.7670
# Epoch 8/10
# 86/86 [==============================] - 2241s 26s/step - loss: 0.5436 - accuracy: 0.8130 - val_loss: 0.6405 - val_accuracy: 0.7747
# Epoch 9/10
# 86/86 [==============================] - 2056s 24s/step - loss: 0.5049 - accuracy: 0.8254 - val_loss: 0.6568 - val_accuracy: 0.7619
# Epoch 10/10
# 86/86 [==============================] - 1935s 23s/step - loss: 0.4515 - accuracy: 0.8407 - val_loss: 0.6653 - val_accuracy: 0.7653
# Found 1680 images belonging to 7 classes.
# 53/53 [==============================] - 893s 17s/step
# Classification Report:
#               precision    recall  f1-score   support
#
#     XR_ELBOW       0.57      0.79      0.66       240
#    XR_FINGER       0.70      0.93      0.79       240
#   XR_FOREARM       0.77      0.53      0.63       240
#      XR_HAND       0.92      0.85      0.89       240
#   XR_HUMERUS       0.84      0.76      0.80       240
#  XR_SHOULDER       0.90      0.84      0.87       240
#     XR_WRIST       0.84      0.70      0.77       240
#
#     accuracy                           0.77      1680
#    macro avg       0.79      0.77      0.77      1680
# weighted avg       0.79      0.77      0.77      1680
# Sensitivity: [0.79166667 0.925      0.53333333 0.85416667 0.75833333 0.84166667
#  0.70416667]
# Specificity: [0.57228916 0.69592476 0.76646707 0.92342342 0.84259259 0.90178571
#  0.845     ]

# %%
#Clearing backend
from tensorflow.keras import backend
backend.clear_session()

#Fixing the seed for random number generators
np.random.seed(1042)
import random
random.seed(1042)
tf.random.set_seed(1042)

# %% [markdown]
# # largedata 64 multiclass 10-Fold CV vgg16

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.models import Model
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import seaborn as sns
from sklearn.model_selection import KFold

# Define paths
train_dir = "C:/Users/OLASUNKANMI/Desktop/UoL DS Course files/Semester C/UoL Research Project Materials/New_Mura/large_dataset/64/Multiclass/train"
test_dir = "C:/Users/OLASUNKANMI/Desktop/UoL DS Course files/Semester C/UoL Research Project Materials/New_Mura/large_dataset/64/Multiclass/test"

# Data Preprocessing
image_size = (64, 64)
batch_size = 32
cv_folds = 10

# Image Data Generators
datagen = ImageDataGenerator(rescale=1./255, validation_split=0.3)

def create_model():
    base_model = VGG16(weights='imagenet', include_top=False, input_shape=(64, 64, 3))
    base_model.trainable = False  # Freeze base model
    
    x = Flatten()(base_model.output)
    x = Dense(512, activation='relu')(x)
    x = Dropout(0.5)(x)
    out = Dense(7, activation='softmax')(x)
    model = Model(inputs=base_model.input, outputs=out)
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# Perform Cross-Validation
kf = KFold(n_splits=cv_folds, shuffle=True, random_state=42)

for fold, (train_index, val_index) in enumerate(kf.split(train_generator.filenames)):
    print(f"Training fold {fold+1}/{cv_folds}")
    
    train_generator = datagen.flow_from_directory(
        train_dir,
        target_size=image_size,
        batch_size=batch_size,
        class_mode='categorical',
        subset='training')
    
    val_generator = datagen.flow_from_directory(
        train_dir,
        target_size=image_size,
        batch_size=batch_size,
        class_mode='categorical',
        subset='validation')
    
    model = create_model()
    history = model.fit(train_generator, validation_data=val_generator, epochs=10)

# Evaluate on Test Data
test_datagen = ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False)

y_true = test_generator.classes
y_pred_probs = model.predict(test_generator)
y_pred = np.argmax(y_pred_probs, axis=1)

# Classification Report
print("Classification Report:")
print(classification_report(y_true, y_pred, target_names=test_generator.class_indices.keys()))

# Confusion Matrix
cm = confusion_matrix(y_true, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=test_generator.class_indices.keys(), yticklabels=test_generator.class_indices.keys())
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# Sensitivity and Specificity
sensitivity = cm.diagonal() / cm.sum(axis=1)
specificity = cm.diagonal() / cm.sum(axis=0)
print("Sensitivity:", sensitivity)
print("Specificity:", specificity)

# Loss Visualization
plt.plot(history.history["loss"], label="Training Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.legend()
plt.title("Training and Validation Loss")
plt.show()
# Out:
# Training fold 1/10
# Found 2744 images belonging to 7 classes.
# Found 1176 images belonging to 7 classes.
# Epoch 1/10
# 86/86 [==============================] - 2068s 24s/step - loss: 1.4150 - accuracy: 0.4832 - val_loss: 1.0212 - val_accuracy: 0.6658
# Epoch 2/10
# 86/86 [==============================] - 1879s 22s/step - loss: 0.9922 - accuracy: 0.6501 - val_loss: 0.8654 - val_accuracy: 0.6896
# Epoch 3/10
# 86/86 [==============================] - 2040s 24s/step - loss: 0.8490 - accuracy: 0.6986 - val_loss: 0.7611 - val_accuracy: 0.7338
# Epoch 4/10
# 86/86 [==============================] - 1969s 23s/step - loss: 0.7625 - accuracy: 0.7362 - val_loss: 0.7581 - val_accuracy: 0.7270
# Epoch 5/10
# 86/86 [==============================] - 1854s 22s/step - loss: 0.6802 - accuracy: 0.7591 - val_loss: 0.7002 - val_accuracy: 0.7560
# Epoch 6/10
# 86/86 [==============================] - 1904s 22s/step - loss: 0.6108 - accuracy: 0.7857 - val_loss: 0.7069 - val_accuracy: 0.7457
# Epoch 7/10
# 86/86 [==============================] - 1681s 20s/step - loss: 0.5912 - accuracy: 0.7952 - val_loss: 0.6807 - val_accuracy: 0.7534
# Epoch 8/10
# 86/86 [==============================] - 1624s 19s/step - loss: 0.5336 - accuracy: 0.8109 - val_loss: 0.6554 - val_accuracy: 0.7670
# Epoch 9/10
# 86/86 [==============================] - 1608s 19s/step - loss: 0.5083 - accuracy: 0.8196 - val_loss: 0.6207 - val_accuracy: 0.7823
# Epoch 10/10
# 86/86 [==============================] - 1604s 19s/step - loss: 0.4725 - accuracy: 0.8382 - val_loss: 0.6402 - val_accuracy: 0.7721
# Training fold 2/10
# Found 2744 images belonging to 7 classes.
# Found 1176 images belonging to 7 classes.
# Epoch 1/10
# 86/86 [==============================] - 1595s 18s/step - loss: 1.3823 - accuracy: 0.5091 - val_loss: 0.9871 - val_accuracy: 0.6735
# Epoch 2/10
# 86/86 [==============================] - 1565s 18s/step - loss: 0.9875 - accuracy: 0.6509 - val_loss: 0.8543 - val_accuracy: 0.7066
# Epoch 3/10
# 86/86 [==============================] - 1644s 19s/step - loss: 0.8552 - accuracy: 0.6950 - val_loss: 0.8105 - val_accuracy: 0.7134
# Epoch 4/10
# 86/86 [==============================] - 1622s 19s/step - loss: 0.7517 - accuracy: 0.7329 - val_loss: 0.7336 - val_accuracy: 0.7219
# Epoch 5/10
# 86/86 [==============================] - 1631s 19s/step - loss: 0.6854 - accuracy: 0.7551 - val_loss: 0.6906 - val_accuracy: 0.7449
# Epoch 6/10
# 86/86 [==============================] - 1609s 19s/step - loss: 0.5936 - accuracy: 0.7905 - val_loss: 0.6761 - val_accuracy: 0.7619
# Epoch 7/10
# 86/86 [==============================] - 1561s 18s/step - loss: 0.5484 - accuracy: 0.8087 - val_loss: 0.6473 - val_accuracy: 0.7534
# Epoch 8/10
# 86/86 [==============================] - 1550s 18s/step - loss: 0.5206 - accuracy: 0.8189 - val_loss: 0.6201 - val_accuracy: 0.7730
# Epoch 9/10
# 86/86 [==============================] - 1659s 19s/step - loss: 0.5009 - accuracy: 0.8305 - val_loss: 0.6324 - val_accuracy: 0.7755
# Epoch 10/10
# 86/86 [==============================] - 1556s 18s/step - loss: 0.4635 - accuracy: 0.8429 - val_loss: 0.6023 - val_accuracy: 0.7891
# Training fold 3/10
# Found 2744 images belonging to 7 classes.
# Found 1176 images belonging to 7 classes.
# Epoch 1/10
# 86/86 [==============================] - 1420s 16s/step - loss: 1.4331 - accuracy: 0.4858 - val_loss: 1.0170 - val_accuracy: 0.6412
# Epoch 2/10
# 86/86 [==============================] - 1733s 20s/step - loss: 0.9798 - accuracy: 0.6662 - val_loss: 0.8458 - val_accuracy: 0.7066
# Epoch 3/10
# 86/86 [==============================] - 1830s 21s/step - loss: 0.8358 - accuracy: 0.7190 - val_loss: 0.8126 - val_accuracy: 0.7058
# Epoch 4/10
# 86/86 [==============================] - 1779s 21s/step - loss: 0.7485 - accuracy: 0.7431 - val_loss: 0.7673 - val_accuracy: 0.7160
# Epoch 5/10
# 86/86 [==============================] - 1874s 22s/step - loss: 0.6757 - accuracy: 0.7726 - val_loss: 0.7096 - val_accuracy: 0.7406
# Epoch 6/10
# 86/86 [==============================] - 1839s 21s/step - loss: 0.6256 - accuracy: 0.7828 - val_loss: 0.6956 - val_accuracy: 0.7423
# Epoch 7/10
# 86/86 [==============================] - 6363s 75s/step - loss: 0.5905 - accuracy: 0.7937 - val_loss: 0.6786 - val_accuracy: 0.7509
# Epoch 8/10
# 86/86 [==============================] - 1444s 17s/step - loss: 0.5479 - accuracy: 0.8127 - val_loss: 0.6730 - val_accuracy: 0.7645
# Epoch 9/10
# 86/86 [==============================] - 1509s 18s/step - loss: 0.5028 - accuracy: 0.8284 - val_loss: 0.6477 - val_accuracy: 0.7611
# Epoch 10/10
# 86/86 [==============================] - 1573s 18s/step - loss: 0.4688 - accuracy: 0.8378 - val_loss: 0.6413 - val_accuracy: 0.7789
# Training fold 4/10
# Found 2744 images belonging to 7 classes.
# Found 1176 images belonging to 7 classes.
# Epoch 1/10
# 86/86 [==============================] - 1534s 18s/step - loss: 1.3928 - accuracy: 0.4971 - val_loss: 1.0049 - val_accuracy: 0.6590
# Epoch 2/10
# 86/86 [==============================] - 1539s 18s/step - loss: 0.9901 - accuracy: 0.6542 - val_loss: 0.8623 - val_accuracy: 0.7075
# Epoch 3/10
# 86/86 [==============================] - 1726s 20s/step - loss: 0.8374 - accuracy: 0.6986 - val_loss: 0.7829 - val_accuracy: 0.7270
# Epoch 4/10
# 86/86 [==============================] - 1787s 21s/step - loss: 0.7394 - accuracy: 0.7391 - val_loss: 0.7550 - val_accuracy: 0.7406
# Epoch 5/10
# 86/86 [==============================] - 1841s 21s/step - loss: 0.6941 - accuracy: 0.7511 - val_loss: 0.6914 - val_accuracy: 0.7381
# Epoch 6/10
# 86/86 [==============================] - 1894s 22s/step - loss: 0.6238 - accuracy: 0.7741 - val_loss: 0.6895 - val_accuracy: 0.7457
# Epoch 7/10
# 86/86 [==============================] - 1985s 23s/step - loss: 0.5770 - accuracy: 0.7941 - val_loss: 0.6486 - val_accuracy: 0.7670
# Epoch 8/10
# 86/86 [==============================] - 1988s 23s/step - loss: 0.5416 - accuracy: 0.8061 - val_loss: 0.6531 - val_accuracy: 0.7696
# Epoch 9/10
# 86/86 [==============================] - 1878s 22s/step - loss: 0.4971 - accuracy: 0.8258 - val_loss: 0.6560 - val_accuracy: 0.7636
# Epoch 10/10
# 86/86 [==============================] - 1874s 22s/step - loss: 0.4904 - accuracy: 0.8258 - val_loss: 0.6180 - val_accuracy: 0.7679
# Training fold 5/10
# Found 2744 images belonging to 7 classes.
# Found 1176 images belonging to 7 classes.
# Epoch 1/10
# 86/86 [==============================] - 1852s 21s/step - loss: 1.4229 - accuracy: 0.4851 - val_loss: 1.0668 - val_accuracy: 0.6318
# Epoch 2/10
# 86/86 [==============================] - 1782s 21s/step - loss: 0.9778 - accuracy: 0.6574 - val_loss: 0.8774 - val_accuracy: 0.6854
# Epoch 3/10
# 86/86 [==============================] - 1679s 20s/step - loss: 0.8152 - accuracy: 0.7267 - val_loss: 0.8314 - val_accuracy: 0.6990
# Epoch 4/10
# 86/86 [==============================] - 1642s 19s/step - loss: 0.7352 - accuracy: 0.7511 - val_loss: 0.7261 - val_accuracy: 0.7372
# Epoch 5/10
# 86/86 [==============================] - 1597s 19s/step - loss: 0.6667 - accuracy: 0.7628 - val_loss: 0.6920 - val_accuracy: 0.7415
# Epoch 6/10
# 86/86 [==============================] - 1584s 18s/step - loss: 0.6150 - accuracy: 0.7850 - val_loss: 0.6979 - val_accuracy: 0.7398
# Epoch 7/10
# 86/86 [==============================] - 1559s 18s/step - loss: 0.5719 - accuracy: 0.7992 - val_loss: 0.6612 - val_accuracy: 0.7670
# Epoch 8/10
# 86/86 [==============================] - 1547s 18s/step - loss: 0.5436 - accuracy: 0.8130 - val_loss: 0.6405 - val_accuracy: 0.7747
# Epoch 9/10
# 86/86 [==============================] - 1446s 17s/step - loss: 0.5049 - accuracy: 0.8254 - val_loss: 0.6568 - val_accuracy: 0.7619
# Epoch 10/10
# 86/86 [==============================] - 1342s 16s/step - loss: 0.4515 - accuracy: 0.8407 - val_loss: 0.6653 - val_accuracy: 0.7653
# Training fold 6/10
# Found 2744 images belonging to 7 classes.
# Found 1176 images belonging to 7 classes.
# Epoch 1/10
# 86/86 [==============================] - 1390s 16s/step - loss: 1.4408 - accuracy: 0.4785 - val_loss: 1.0130 - val_accuracy: 0.6514
# Epoch 2/10
# 86/86 [==============================] - 1355s 16s/step - loss: 0.9969 - accuracy: 0.6458 - val_loss: 0.8870 - val_accuracy: 0.6998
# Epoch 3/10
# 86/86 [==============================] - 1366s 16s/step - loss: 0.8509 - accuracy: 0.7019 - val_loss: 0.7931 - val_accuracy: 0.7313
# Epoch 4/10
# 86/86 [==============================] - 1377s 16s/step - loss: 0.7600 - accuracy: 0.7296 - val_loss: 0.7448 - val_accuracy: 0.7372
# Epoch 5/10
# 86/86 [==============================] - 1384s 16s/step - loss: 0.6617 - accuracy: 0.7693 - val_loss: 0.7012 - val_accuracy: 0.7440
# Epoch 6/10
# 86/86 [==============================] - 1317s 15s/step - loss: 0.6291 - accuracy: 0.7762 - val_loss: 0.6636 - val_accuracy: 0.7509
# Epoch 7/10
# 86/86 [==============================] - 1308s 15s/step - loss: 0.5945 - accuracy: 0.7894 - val_loss: 0.6753 - val_accuracy: 0.7457
# Epoch 8/10
# 86/86 [==============================] - 1266s 15s/step - loss: 0.5358 - accuracy: 0.8076 - val_loss: 0.6559 - val_accuracy: 0.7662
# Epoch 9/10
# 86/86 [==============================] - 1259s 15s/step - loss: 0.5203 - accuracy: 0.8185 - val_loss: 0.6330 - val_accuracy: 0.7747
# Epoch 10/10
# 86/86 [==============================] - 1271s 15s/step - loss: 0.4805 - accuracy: 0.8305 - val_loss: 0.6298 - val_accuracy: 0.7713
# Training fold 7/10
# Found 2744 images belonging to 7 classes.
# Found 1176 images belonging to 7 classes.
# Epoch 1/10
# 86/86 [==============================] - 1210s 14s/step - loss: 1.4109 - accuracy: 0.4847 - val_loss: 0.9908 - val_accuracy: 0.6709
# Epoch 2/10
# 86/86 [==============================] - 1143s 13s/step - loss: 0.9529 - accuracy: 0.6673 - val_loss: 0.8700 - val_accuracy: 0.7041
# Epoch 3/10
# 86/86 [==============================] - 1159s 14s/step - loss: 0.8318 - accuracy: 0.7048 - val_loss: 0.7741 - val_accuracy: 0.7423
# Epoch 4/10
# 86/86 [==============================] - 1159s 14s/step - loss: 0.7395 - accuracy: 0.7420 - val_loss: 0.7540 - val_accuracy: 0.7321
# Epoch 5/10
# 86/86 [==============================] - 1159s 14s/step - loss: 0.6823 - accuracy: 0.7617 - val_loss: 0.7149 - val_accuracy: 0.7321
# Epoch 6/10
# 86/86 [==============================] - 1133s 13s/step - loss: 0.6088 - accuracy: 0.7799 - val_loss: 0.6756 - val_accuracy: 0.7670
# Epoch 7/10
# 86/86 [==============================] - 1155s 13s/step - loss: 0.5669 - accuracy: 0.8036 - val_loss: 0.6437 - val_accuracy: 0.7619
# Epoch 8/10
# 86/86 [==============================] - 1156s 13s/step - loss: 0.5470 - accuracy: 0.8090 - val_loss: 0.6755 - val_accuracy: 0.7534
# Epoch 9/10
# 86/86 [==============================] - 5226s 61s/step - loss: 0.5220 - accuracy: 0.8156 - val_loss: 0.6268 - val_accuracy: 0.7721
# Epoch 10/10
# 86/86 [==============================] - 1172s 14s/step - loss: 0.4662 - accuracy: 0.8345 - val_loss: 0.6574 - val_accuracy: 0.7713
# Training fold 8/10
# Found 2744 images belonging to 7 classes.
# Found 1176 images belonging to 7 classes.
# Epoch 1/10
# 86/86 [==============================] - 1170s 13s/step - loss: 1.4523 - accuracy: 0.4654 - val_loss: 1.0182 - val_accuracy: 0.6556
# Epoch 2/10
# 86/86 [==============================] - 1300s 15s/step - loss: 0.9698 - accuracy: 0.6633 - val_loss: 0.9201 - val_accuracy: 0.6871
# Epoch 3/10
# 86/86 [==============================] - 1300s 15s/step - loss: 0.8398 - accuracy: 0.7081 - val_loss: 0.7723 - val_accuracy: 0.7296
# Epoch 4/10
# 86/86 [==============================] - 1326s 15s/step - loss: 0.7455 - accuracy: 0.7413 - val_loss: 0.7748 - val_accuracy: 0.7236
# Epoch 5/10
# 86/86 [==============================] - 1303s 15s/step - loss: 0.6635 - accuracy: 0.7602 - val_loss: 0.7342 - val_accuracy: 0.7440
# Epoch 6/10
# 86/86 [==============================] - 1294s 15s/step - loss: 0.6327 - accuracy: 0.7832 - val_loss: 0.6876 - val_accuracy: 0.7457
# Epoch 7/10
# 86/86 [==============================] - 1345s 16s/step - loss: 0.5780 - accuracy: 0.7956 - val_loss: 0.6472 - val_accuracy: 0.7704
# Epoch 8/10
# 86/86 [==============================] - 1306s 15s/step - loss: 0.5472 - accuracy: 0.8112 - val_loss: 0.6764 - val_accuracy: 0.7517
# Epoch 9/10
# 86/86 [==============================] - 1321s 15s/step - loss: 0.5062 - accuracy: 0.8181 - val_loss: 0.6124 - val_accuracy: 0.7840
# Epoch 10/10
# 86/86 [==============================] - 1352s 16s/step - loss: 0.4808 - accuracy: 0.8353 - val_loss: 0.6376 - val_accuracy: 0.7772
# Training fold 9/10
# Found 2744 images belonging to 7 classes.
# Found 1176 images belonging to 7 classes.
# Epoch 1/10
# 86/86 [==============================] - 1443s 17s/step - loss: 1.4228 - accuracy: 0.4920 - val_loss: 1.0729 - val_accuracy: 0.6386
# Epoch 2/10
# 86/86 [==============================] - 1430s 17s/step - loss: 0.9803 - accuracy: 0.6622 - val_loss: 0.8445 - val_accuracy: 0.7100
# Epoch 3/10
# 86/86 [==============================] - 1438s 17s/step - loss: 0.8374 - accuracy: 0.7139 - val_loss: 0.8223 - val_accuracy: 0.7177
# Epoch 4/10
# 86/86 [==============================] - 26500s 312s/step - loss: 0.7568 - accuracy: 0.7314 - val_loss: 0.8051 - val_accuracy: 0.6922
# Epoch 5/10
# 86/86 [==============================] - 1684s 20s/step - loss: 0.6925 - accuracy: 0.7569 - val_loss: 0.7201 - val_accuracy: 0.7330
# Epoch 6/10
# 86/86 [==============================] - 2675s 31s/step - loss: 0.6278 - accuracy: 0.7737 - val_loss: 0.6837 - val_accuracy: 0.7551
# Epoch 7/10
# 86/86 [==============================] - 4305s 50s/step - loss: 0.5623 - accuracy: 0.7988 - val_loss: 0.6599 - val_accuracy: 0.7679
# Epoch 8/10
# 86/86 [==============================] - 1991s 23s/step - loss: 0.5328 - accuracy: 0.8149 - val_loss: 0.6416 - val_accuracy: 0.7704
# Epoch 9/10
# 86/86 [==============================] - 2021s 24s/step - loss: 0.4915 - accuracy: 0.8276 - val_loss: 0.6415 - val_accuracy: 0.7704
# Epoch 10/10
# 86/86 [==============================] - 2052s 24s/step - loss: 0.4533 - accuracy: 0.8418 - val_loss: 0.6880 - val_accuracy: 0.7653
# Training fold 10/10
# Found 2744 images belonging to 7 classes.
# Found 1176 images belonging to 7 classes.
# Epoch 1/10
# 86/86 [==============================] - 2035s 23s/step - loss: 1.4510 - accuracy: 0.4723 - val_loss: 1.0244 - val_accuracy: 0.6548
# Epoch 2/10
# 86/86 [==============================] - 24475s 288s/step - loss: 0.9969 - accuracy: 0.6494 - val_loss: 0.8704 - val_accuracy: 0.6879
# Epoch 3/10
# 86/86 [==============================] - 1394s 16s/step - loss: 0.8477 - accuracy: 0.7041 - val_loss: 0.8514 - val_accuracy: 0.6786
# Epoch 4/10
# 86/86 [==============================] - 2077s 24s/step - loss: 0.7705 - accuracy: 0.7329 - val_loss: 0.7768 - val_accuracy: 0.7126
# Epoch 5/10
# 86/86 [==============================] - 2171s 25s/step - loss: 0.6820 - accuracy: 0.7587 - val_loss: 0.7084 - val_accuracy: 0.7500
# Epoch 6/10
# 86/86 [==============================] - 6734s 79s/step - loss: 0.6239 - accuracy: 0.7872 - val_loss: 0.7237 - val_accuracy: 0.7423
# Epoch 7/10
# 86/86 [==============================] - 1897s 22s/step - loss: 0.5973 - accuracy: 0.7857 - val_loss: 0.7179 - val_accuracy: 0.7432
# Epoch 8/10
# 86/86 [==============================] - 1561s 18s/step - loss: 0.5622 - accuracy: 0.8047 - val_loss: 0.7212 - val_accuracy: 0.7304
# Epoch 9/10
# 86/86 [==============================] - 1563s 18s/step - loss: 0.5095 - accuracy: 0.8240 - val_loss: 0.6481 - val_accuracy: 0.7772
# Epoch 10/10
# 86/86 [==============================] - 1816s 21s/step - loss: 0.4889 - accuracy: 0.8345 - val_loss: 0.6610 - val_accuracy: 0.7653
# Found 1680 images belonging to 7 classes.
# 53/53 [==============================] - 851s 16s/step
# Classification Report:
#               precision    recall  f1-score   support
#
#     XR_ELBOW       0.65      0.74      0.69       240
#    XR_FINGER       0.84      0.81      0.82       240
#   XR_FOREARM       0.58      0.70      0.63       240
#      XR_HAND       0.92      0.83      0.88       240
#   XR_HUMERUS       0.77      0.81      0.79       240
#  XR_SHOULDER       0.86      0.87      0.86       240
#     XR_WRIST       0.89      0.65      0.75       240
#
#     accuracy                           0.77      1680
#    macro avg       0.79      0.77      0.78      1680
# weighted avg       0.79      0.77      0.78      1680
# Sensitivity: [0.7375     0.8125     0.69583333 0.83333333 0.80833333 0.86666667
#  0.65416667]
# Specificity: [0.6459854  0.83690987 0.58188153 0.92165899 0.77290837 0.85950413
#  0.89204545]
